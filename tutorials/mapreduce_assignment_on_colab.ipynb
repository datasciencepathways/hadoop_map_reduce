# %% [markdown]
# <a href="https://colab.research.google.com/github/datasciencepathways/hadoop_map_reduce/blob/main/tutorials/mapreduce_assignment_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# ## **Assignment: Running and Analyzing Hadoop MapReduce**
# **Module 2.3**
# **Block : Big Data Processing and NLP**
#
#
#
# In this assignment, you will run and analyze the performance of a MapReduce job by adjusting its runtime parameters. You will complete the assignment in the Google Colab environment. You will then upload the notebook to Canvas and take a short quiz to answer some questions.
#
# The main tasks for this assignment are as follows.
#
# 1. [Install Hadoop](#hadoop)
# 2. [Obtain the MapReduce Code](#get_code)
# 3. [Obtain Input Dataset](#get_input)
# 4. [Run MapReduce](#mapreduce)
# 5. [Submission](#end)

# %% [markdown]
# ## <a name="hadoop"></a>1. Install Hadoop
# Install Hadoop in Colab. You can follow the instructions from the previous tutorials. The steps are outlined below. You will need to fill in the appropriate commands in the input cells.
#
# 1.1. Download Hadoop version 3.3.1

# %%
# !wget https://dlcdn.apache.org/hadoop/common/hadoop-3.3.1/hadoop-3.3.1.tar.gz

# %% [markdown]
# 1.2  Untar and unzip the archive.

# %% [markdown]
# 1.3 Check to see if Hadoop binaries had been extracted.

# %% [markdown]
# 1.4 Copy the Hadoop file to a system location (`/usr/local`)

# %% [markdown]
# 1.5 Locate the path for Java

# %% [markdown]
# 1.6 Edit `/usr/local/hadoop-3.3.0/etc/hadoop/hadoop-env.sh` file and add the JAVA_HOME path.

# %% [markdown]
# 1.7 Format the disk with HDFS

# %% [markdown]
# 1.8 Check if Hadoop installation has been successful.

# %% [markdown]
# ## <a name="get_code"></a>2. Obtain the MapReduce Code
#
# In this assignment, you will again be working with the Word Count MapReduce program.
#
# 2.1 Obtain the MapReduce code from the Git repo.

# %%
# !git clone https://github.com/apanqasem/hadoop_map_reduce.git

# %% [markdown]
# 2.2 Copy the mapper and reducer codes  to the current directory.

# %% [markdown]
# 2.3. Set `execute` permissions on the two files.

# %% [markdown]
# ## <a name="get_input"></a>3. Obtain the Input Dataset
#
# 3.1 Create the input directory.

# %% [markdown]
# 3.2 Copy the IMDB movie reviews dataset 1 to the input directory (the dataset is included in the Git repo).

# %% [markdown]
# ## <a name="mapreduce"></a>4. Run the MapReduce Job
#
# 4.1 Run the MapReduce code with default arguments.
#
# ```bash
# hadoop jar hadoop-streaming.jar \
# -input name_of_input_file \
# -output name_of_output_directory \
# -file name_of_mapper_file \
# -mapper the_mapper_cmd \
# -file name_of_reducer_file \
# -reducer the_reducer_cmd \
# ```

# %% [markdown]
# 4.2 Check the contents of the output file (make sure output file has been recently created)

# %% [markdown]
# 4.2 Run the MapReduce task with two reducers and measure the execution time of the program.

# %% [markdown]
# 4.3 Sort the words in the output file by their frequency and study the output.

# %% [markdown]
# ## <a name="end"></a>5. Submission
#
# There are two parts two your submission.
#
# 1. Save this notebook as `block9_assignment_2_your_lastname.ipynb` and upload the file through the assignment submission portal.
#
# 2. Take the Assignment 2 Quiz. You will need to reference the output from this notebook to answer the questions on the Quiz.
